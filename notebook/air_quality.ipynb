# %%
import pandas as pd
import matplotlib.pyplot as plt

air_quality = pd.read_csv('../file/air_quality_no2.csv', index_col=0, parse_dates=True)
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
air_quality['station_paris'].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
air_quality.plot.scatter(x='station_london', y='station_paris', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.area(figsize=(20,10), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>], dtype=object)

# %%
fig, axs = plt.subplots(figsize=(12,4))
air_quality.plot.area(ax=axs)
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
axs.set_ylabel('NO$_2$ concentration')
# Out:
# Text(3.200000000000017, 0.5, 'NO$_2$ concentration')

# %%
fig.savefig('no2_concentration.png')

# %%
air_quality_renamed = air_quality.rename(columns={'station_london': 'London Westminster'})
air_quality_renamed
# Out:
#                      station_antwerp  station_paris  London Westminster
# datetime
# 2019-05-07 02:00:00              NaN            NaN                23.0
# 2019-05-07 03:00:00             50.5           25.0                19.0
# 2019-05-07 04:00:00             45.0           27.7                19.0
# 2019-05-07 05:00:00              NaN           50.4                16.0
# 2019-05-07 06:00:00              NaN           61.9                 NaN
# ...                              ...            ...                 ...
# 2019-06-20 22:00:00              NaN           21.4                 NaN
# 2019-06-20 23:00:00              NaN           24.9                 NaN
# 2019-06-21 00:00:00              NaN           26.5                 NaN
# 2019-06-21 01:00:00              NaN           21.8                 NaN
# 2019-06-21 02:00:00              NaN           20.0                 NaN
#
# [1035 rows x 3 columns]

# %%
air_quality_renamed.rename(columns=str.lower)
# Out:
#                      station_antwerp  station_paris  london westminster
# datetime
# 2019-05-07 02:00:00              NaN            NaN                23.0
# 2019-05-07 03:00:00             50.5           25.0                19.0
# 2019-05-07 04:00:00             45.0           27.7                19.0
# 2019-05-07 05:00:00              NaN           50.4                16.0
# 2019-05-07 06:00:00              NaN           61.9                 NaN
# ...                              ...            ...                 ...
# 2019-06-20 22:00:00              NaN           21.4                 NaN
# 2019-06-20 23:00:00              NaN           24.9                 NaN
# 2019-06-21 00:00:00              NaN           26.5                 NaN
# 2019-06-21 01:00:00              NaN           21.8                 NaN
# 2019-06-21 02:00:00              NaN           20.0                 NaN
#
# [1035 rows x 3 columns]
