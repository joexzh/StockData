# %%
cd ..
# Out:
# E:\github\joexzh

# %% [markdown]
# ## 当天涨幅排序

# %%
import view

df = view.pct_chg_sort(0)
df
# Out:
# login success!
# query_trade_dates respond error_code:0
# query_trade_dates respond error_msg:success
# query_stock_basic respond error_code:0
# query_stock_basic respond error_msg:success
# logout success!
#           date       code code_name     close            amount     pctChg
# 0   2021-07-29  sz.300852      四会富仕   57.8800    527186569.4100  20.008301
# 1   2021-07-29  sz.300693      盛弘股份   29.9900    837292866.0800  20.007999
# 2   2021-07-29  sz.300827      上能电气  107.7400   1392267742.7500  20.004499
# 3   2021-07-29  sz.300648      星云股份   54.7100    916273820.4400  20.004400
# 4   2021-07-29  sz.300576      容大感光   51.9600   1215529758.1500  20.000000
# 5   2021-07-29  sz.300077      国民技术   42.0600   4075727116.5200  20.000000
# 6   2021-07-29  sz.300346      南大光电   69.9600   5976097359.3900  20.000000
# 7   2021-07-29  sz.300661      圣邦股份  332.4800   1861037802.1300  19.998600
# 8   2021-07-29  sz.300712      永福股份  102.7300    811908429.6100  19.997700
# ...

# %%
l0 = df['code'].tolist()
with open(r'C:\Users\Administrator\Documents\当天涨幅排序.txt', 'w') as f:
    f.write(str(l0))
l0
# Out:
# ['sz.300852',
#  'sz.300693',
#  'sz.300827',
#  'sz.300648',
#  'sz.300576',
#  'sz.300077',
#  'sz.300346',
#  'sz.300661',
#  'sz.300712',
#  'sz.300274',
#  'sz.300101',
#  'sz.300432',
#  'sz.300040',
#  'sz.300537',
#  'sz.300460',
#  'sz.300752',
#  'sz.300128',
#  'sz.300301',
#  'sz.300438',
#  'sz.300763',
#  'sz.300613',
#  'sz.300316',
#  'sz.300450',
#  'sz.300142',
#  'sz.300294',
#  'sz.300655',
#  'sz.300171',
#  'sz.300207',
#  'sz.300382',
#  'sz.300490',
#  'sz.300687',
#  'sz.300751',
#  'sz.300343',
#  'sz.300252',
#  'sz.300160',
#  'sz.300672',
#  'sz.300036',
#  'sz.300476',
#  'sz.300394',
#  'sz.300739',
#  'sz.300331',
#  'sz.300398',
#  'sz.300236',
#  'sz.300241',
#  'sz.300769',
#  'sz.300477',
#  'sz.002288',
#  'sh.601636',
#  'sz.002455',
#  'sh.600206',
#  'sz.000009',
#  'sh.603220',
#  'sh.600745',
#  'sz.002119',
#  'sz.002192',
#  'sh.605020',
#  'sz.002129',
#  'sh.603806',
#  'sh.603267',
#  'sz.002756',
#  'sz.002222',
#  'sh.603650',
# ...

# %% [markdown]
# ## 1天前涨幅排序

# %%
df1 = view.pct_chg_sort(1)
df1
# Out:
# login success!
# query_trade_dates respond error_code:0
# query_trade_dates respond error_msg:success
# query_stock_basic respond error_code:0
# query_stock_basic respond error_msg:success
# logout success!
#           date       code code_name     close            amount     pctChg
# 0   2021-07-28  sz.300570       太辰光   20.0800    616786957.6400  20.023899
# 1   2021-07-28  sz.301021      英诺激光   58.6600    866127576.9700  20.008200
# 2   2021-07-28  sz.300106      西部牧业   11.8800    577784651.7100  20.000000
# 3   2021-07-28  sz.300827      上能电气   89.7800   1043070204.3900  19.994699
# 4   2021-07-28  sz.300660      江苏雷利   33.7900    629442664.6700  19.992901
# 5   2021-07-28  sz.300343      联创股份   12.2500   2476841490.5300  19.980400
# 6   2021-07-28  sz.300739      明阳电路   21.9800    831444457.2400  16.666700
# 7   2021-07-28  sz.300346      南大光电   58.3000   4520177946.4400  15.217400
# 8   2021-07-28  sz.300244      迪安诊断   34.7500    601352818.5500  13.636400
# ...

# %%
l1 = df1['code'].tolist()
with open(r'C:\Users\Administrator\Documents\1天前涨幅排序.txt', 'w') as f:
  f.write(str(l1))
l1
# Out:
# ['sz.300570',
#  'sz.301021',
#  'sz.300106',
#  'sz.300827',
#  'sz.300660',
#  'sz.300343',
#  'sz.300739',
#  'sz.300346',
#  'sz.300244',
#  'sz.300648',
#  'sz.300480',
#  'sz.300763',
#  'sz.300223',
#  'sz.300759',
#  'sh.605020',
#  'sh.603198',
#  'sh.603876',
#  'sz.002030',
#  'sz.002271',
#  'sz.002598',
#  'sz.002580',
#  'sz.002455',
#  'sh.600366',
#  'sz.002821',
#  'sz.300896',
#  'sh.600348',
#  'sz.002603',
#  'sz.300676',
#  'sh.600295',
#  'sz.002418',
#  'sh.603283',
#  'sh.600763',
#  'sz.300502',
#  'sz.300590',
#  'sz.300035',
#  'sh.600259',
#  'sz.300394',
#  'sz.300750',
#  'sz.300677',
#  'sh.603396',
#  'sz.002709',
#  'sz.300760',
#  'sh.603259',
#  'sz.300438',
#  'sz.300604',
#  'sz.300432',
#  'sz.300363',
#  'sz.002281',
#  'sz.300413',
#  'sh.600006',
#  'sz.002570',
#  'sz.300751',
#  'sh.601179',
#  'sz.300012',
#  'sz.300903',
#  'sz.002382',
#  'sh.600132',
#  'sz.002078',
#  'sh.600436',
#  'sh.600418',
#  'sz.002192',
#  'sh.600845',
# ...

# %% [markdown]
# ## 2天前涨幅排序

# %%
df2 = view.pct_chg_sort(2)
df2
# Out:
# login success!
# query_trade_dates respond error_code:0
# query_trade_dates respond error_msg:success
# query_stock_basic respond error_code:0
# query_stock_basic respond error_msg:success
# logout success!
#           date       code code_name     close            amount     pctChg
# 0   2021-07-27  sz.300706       阿石创   36.2900    591087189.1500  20.006599
# 1   2021-07-27  sz.300852      四会富仕   51.9500    508311526.4300  20.004601
# 2   2021-07-27  sz.300990      同飞股份   97.0800    517558226.8000  17.119101
# 3   2021-07-27  sz.300476      胜宏科技   23.2700   1210428301.8700  15.084100
# 4   2021-07-27  sz.300681       英搏尔   67.9600    547310391.5400  13.721600
# 5   2021-07-27  sz.300308      中际旭创   38.1700    886331234.2800  13.533600
# 6   2021-07-27  sz.300850       新强联  127.1300    974228203.2400  12.743900
# 7   2021-07-27  sz.300655      晶瑞股份   49.0900   3244512322.0900  11.264700
# 8   2021-07-27  sz.300129      泰胜风能    7.8200    828452444.4500  11.237600
# ...

# %%
l2 = df2['code'].tolist()
with open(r'C:\Users\Administrator\Documents\2天前涨幅排序.txt', 'w') as f:
  f.write(str(l2))  
l2
# Out:
# ['sz.300706',
#  'sz.300852',
#  'sz.300990',
#  'sz.300476',
#  'sz.300681',
#  'sz.300308',
#  'sz.300850',
#  'sz.300655',
#  'sz.300129',
#  'sz.300077',
#  'sz.300265',
#  'sh.600331',
#  'sz.000506',
#  'sz.002201',
#  'sh.600183',
#  'sh.605056',
#  'sz.002897',
#  'sh.603218',
#  'sz.002463',
#  'sh.603127',
#  'sz.300369',
#  'sh.600745',
#  'sz.300046',
#  'sz.300397',
#  'sh.600582',
#  'sz.300123',
#  'sh.600313',
#  'sz.002579',
#  'sh.600006',
#  'sh.600667',
#  'sz.300379',
#  'sz.002531',
#  'sz.002151',
#  'sz.002079',
#  'sz.300113',
#  'sz.002123',
#  'sh.600845',
#  'sz.002455',
#  'sh.600256',
#  'sz.300183',
#  'sh.600188',
#  'sh.600905',
#  'sz.300346',
#  'sz.300460',
#  'sz.300036',
#  'sz.300383',
#  'sz.300666',
#  'sh.601899',
#  'sh.603078',
#  'sz.300373',
#  'sh.600487',
#  'sz.002281',
#  'sh.603501',
#  'sh.603650']

# %% [markdown]
# ## 3天前涨幅排序

# %%
df3 = view.pct_chg_sort(3)
df3
# Out:
# login success!
# query_trade_dates respond error_code:0
# query_trade_dates respond error_msg:success
# query_stock_basic respond error_code:0
# query_stock_basic respond error_msg:success
# logout success!
#           date       code code_name     close            amount   pctChg
# 0   2021-07-26  sz.300762      上海瀚讯   30.1600    749635451.5200  20.0159
# 1   2021-07-26  sz.300343      联创股份   10.1000   1995753402.0600  17.4419
# 2   2021-07-26  sz.300545      联得装备   33.3000    666452742.2000  17.2948
# 3   2021-07-26  sz.300827      上能电气   76.1800    850777058.8100  15.6696
# 4   2021-07-26  sz.300855      图南股份   50.0000    572476225.8700  12.9944
# 5   2021-07-26  sz.300208      青岛中程   14.5100   2062390448.2400  12.8305
# 6   2021-07-26  sz.300241      瑞丰光电   13.4100   2373786767.9800  12.6891
# 7   2021-07-26  sz.300223      北京君正  165.0000   2540153683.7900  12.4208
# 8   2021-07-26  sz.300604      长川科技   53.8000   1088413820.1600  12.1768
# ...

# %%
l3 = df3['code'].tolist()
with open(r'C:\Users\Administrator\Documents\3天前涨幅排序.txt', 'w') as f:
  f.write(str(l3))  
l3
# Out:
# ['sz.300762',
#  'sz.300343',
#  'sz.300545',
#  'sz.300827',
#  'sz.300855',
#  'sz.300208',
#  'sz.300241',
#  'sz.300223',
#  'sz.300604',
#  'sz.300117',
#  'sz.002503',
#  'sh.601179',
#  'sz.002170',
#  'sh.600331',
#  'sz.002418',
#  'sh.600888',
#  'sz.002506',
#  'sh.601606',
#  'sz.000572',
#  'sh.601921',
#  'sz.002121',
#  'sz.002436',
#  'sh.600773',
#  'sh.600348',
#  'sz.002580',
#  'sh.600497',
#  'sz.300693',
#  'sz.002466',
#  'sh.600685',
#  'sz.000683',
#  'sz.002651',
#  'sz.300655',
#  'sh.600406',
#  'sz.300382',
#  'sh.600552',
#  'sz.002167',
#  'sh.605117',
#  'sz.002625',
#  'sz.002442',
#  'sz.300129',
#  'sz.000821',
#  'sh.600460',
#  'sz.002455',
#  'sz.300825',
#  'sh.600641',
#  'sz.002623',
#  'sh.600399',
#  'sz.300712',
#  'sz.300471',
#  'sz.000561',
#  'sz.002945',
#  'sz.300763',
#  'sz.002269',
#  'sz.002025',
#  'sz.300582',
#  'sz.002245',
#  'sz.300303',
#  'sh.601877',
#  'sz.000400',
#  'sz.002598',
#  'sz.000733',
#  'sz.002049',
# ...
